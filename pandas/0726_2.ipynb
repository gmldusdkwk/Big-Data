# %%
import pandas as pd

# %%
apt = pd.read_csv('apt_final.csv')

# %%
apt.head()
# Out:
#    price_per_area     price  con_year  year dong       aptnm  month   dat  \
# 0            1979   71000.0      1982  2009  개포동    개포주공 3단지     10  1~10
# 1            1994   83700.0      1982  2009  개포동    개포주공 1단지     10  1~10
# 2            1128  173500.0      2004  2009  개포동  개포자이(12-2)     10  1~10
# 3            1204   65000.0      1983  2009  개포동    개포주공 5단지     10  1~10
# 4            1214  160000.0      1986  2009  개포동         현대2     10  1~10
#
#      area area_sub  ...   seoul_cons_ratio  bond_one_year bond_three_year  \
# 0   35.87    small  ...          10.061728           3.52            4.47
# 1   41.98    small  ...          10.061728           3.52            4.47
# 2  153.80    large  ...          10.061728           3.52            4.47
# 3   53.98    small  ...          10.061728           3.52            4.47
# 4  131.83    large  ...          10.061728           3.52            4.47
#
# ...

# %%
apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429466 entries, 0 to 429465
# Data columns (total 62 columns):
# price_per_area          429466 non-null int64
# price                   429466 non-null float64
# con_year                429466 non-null int64
# year                    429466 non-null int64
# dong                    429466 non-null object
# aptnm                   429466 non-null object
# month                   429466 non-null int64
# dat                     429466 non-null object
# area                    429466 non-null float64
# area_sub                429466 non-null object
# loc                     429466 non-null int64
# floor                   429466 non-null int64
# qrt                     429466 non-null object
# yyyyqrt                 429466 non-null object
# yyyym                   429466 non-null int64
# gu                      429466 non-null object
# num_children            429466 non-null int64
# num_elementary          429466 non-null int64
# ...

# %%
apt.gu
# Out:
# 0         강남구
# 1         강남구
# 2         강남구
# 3         강남구
# 4         강남구
# 5         강남구
# 6         강남구
# 7         강남구
# 8         강남구
# 9         강남구
# 10        강남구
# 11        강남구
# 12        강남구
# 13        강남구
# 14        강남구
# 15        강남구
# 16        강남구
# 17        강남구
# 18        강남구
# 19        강남구
# 20        강남구
# 21        강남구
# 22        강남구
# 23        강남구
# 24        강남구
# 25        강남구
# 26        강남구
# 27        강남구
# 28        강남구
# 29        강남구
#          ...
# 429436    중랑구
# 429437    중랑구
# 429438    중랑구
# 429439    중랑구
# 429440    중랑구
# 429441    중랑구
# 429442    중랑구
# 429443    중랑구
# 429444    중랑구
# 429445    중랑구
# 429446    중랑구
# 429447    중랑구
# 429448    중랑구
# 429449    중랑구
# 429450    중랑구
# 429451    중랑구
# 429452    중랑구
# 429453    중랑구
# 429454    중랑구
# 429455    중랑구
# 429456    중랑구
# 429457    중랑구
# 429458    중랑구
# 429459    중랑구
# 429460    중랑구
# 429461    중랑구
# 429462    중랑구
# 429463    중랑구
# 429464    중랑구
# 429465    중랑구
# ...

# %%
len(apt[apt['gu'].isin(['강남구'])])
# Out:
# 38922

# %%
apt.filter(items='gu')

# %%
Gangnamgu = ['개포동', '논현동', '대치동', '일원동', '수서동', '도곡동', '삼성동', '세곡동', '자곡동', '율현동', '신사동', '압구정동', '역삼동', '청담동']

# %%
len(apt[apt['dong'].isin(Gangnamgu)])
# Out:
# 39756

# %%
apt[apt.dong.isin(Gangnamgu)].price_per_area.mean()
# Out:
# 1159.915258074253

# %%
Gangnamgu1 = ["신사동", "압구정1동","압구정2동", "논현동","논현1동","논현2동", "청담동", "청담1동","청담2동", "삼성동","삼성1동","삼성2동","대치동","대치1동","대치2동","대치3동", "대치4동","역삼동","역삼1동","역삼2동","도곡동","도곡1동","도곡2동", "개포동","개포1동","개포2동", "개포3동","개포4동","일원본동", "일원동","일원1동","일원2동", "수서동","세곡동"]

# %%
len(apt.dong.isin(Gangnamgu1))
# Out:
# 429466

# %%
list(map(lambda x: x in Gangnamgu1, apt.dong))  # isin 의 역할
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
data = pd.read_csv('data-zillow.csv')

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=10830, step=1),
#  Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#         'SizeRank', 'Zhvi'],
#        dtype='object')]

# %%
len(data.axes)
# Out:
# 2

# %%
data.axes[0]  # row
# Out:
# RangeIndex(start=0, stop=10830, step=1)

# %%
data.axes[1]  # column
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
data.axes[1] == data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %% [markdown]
# ## qgrid 이용해서 쉽게 filtering 할 수 있다.
# https://github.com/quantopian/qgrid

# %% [markdown]
# ## axis = 0

# %%
data.mean(axis = 0)
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
data.mean(axis = 'rows')
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %% [markdown]
# ## axis = 1

# %%
data.mean(axis = 1).head()
# Out:
# 0    226193.666667
# 1    214116.000000
# 2     80042.666667
# 3     50191.333333
# 4     83876.666667
# dtype: float64

# %%
data.mean(axis = 'columns').head()
# Out:
# 0    226193.666667
# 1    214116.000000
# 2     80042.666667
# 3     50191.333333
# 4     83876.666667
# dtype: float64

# %%
data['RegionID'].max()  # DataFrame에서는 axis가 필요 없다.
# Out:
# 737791

# %% [markdown]
# ## Regular Expression

# %%
net = pd.read_csv('data-netflix.csv', encoding='CP949',index_col='title')

# %%
net.filter(regex = 'Anato', axis = 0)
# Out:
#                rating                                        ratingLevel  \
# title
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#                 ratingDescription  release year  user rating score  \
# title
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# ...

# %% [markdown]
# ## Read in the dataset

# %%
data.info()  # object = string -> Regular Expression
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %% [markdown]
# ## Check for a substring

# %%
data.RegionName.str  # object 일 경우에 str가 된다.

# %%
data['RegionName'] = data.RegionName.str.upper()

# %%
data.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      NEW YORK    NY                        New York
# 1  2017-05-31     12447   LOS ANGELES    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       CHICAGO    IL                         Chicago
# 3  2017-05-31     13271  PHILADELPHIA    PA                    Philadelphia
# 4  2017-05-31     40326       PHOENIX    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %% [markdown]
# ## 함수에서 제일 중요한 것
# 1. map
# 2. reduce
# 3. filter

# %%
data.RegionName.map(lambda x: x+' Plus').head() # column 하나씩 변경
# Out:
# 0        NEW YORK Plus
# 1     LOS ANGELES Plus
# 2         CHICAGO Plus
# 3    PHILADELPHIA Plus
# 4         PHOENIX Plus
# Name: RegionName, dtype: object

# %%
data['new']  = data.County.str.len() #add new column

# %%
data.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      NEW YORK    NY                        New York
# 1  2017-05-31     12447   LOS ANGELES    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       CHICAGO    IL                         Chicago
# 3  2017-05-31     13271  PHILADELPHIA    PA                    Philadelphia
# 4  2017-05-31     40326       PHOENIX    AZ                         Phoenix
#
#          County  SizeRank    Zhvi  new
# 0        Queens         0  672400    6
# 1   Los Angeles         1  629900   11
# 2          Cook         2  222700    4
# 3  Philadelphia         3  137300   12
# 4      Maricopa         4  211300    8

# %% [markdown]
# ## Aggregation

# %%
apt2 = apt[['year', 'price']]

# %%
apt2 = apt2.groupby('year').mean()  # 연도별 평균

# %%
apt2.plot.bar()
