# %% [markdown]
# # 형태소 분석

# %% [markdown]
# ## 영어

# %%
from nltk.corpus import gutenberg

# %%
corpus = gutenberg.open('austen-emma.txt').read()

# %%
from nltk import regexp_tokenize, Text

# %%
pattern = r"([a-zA-Z0-9]+)+"

# %%
tokens = regexp_tokenize(corpus, pattern)

# %%
len(tokens)
# Out:
# 161980

# %%
en = Text(tokens)

# %%
type(en)
# Out:
# nltk.text.Text

# %% [markdown]
# ## 한글

# %%
from konlpy.corpus import kolaw

# %%
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
corpus = kolaw.open('constitution.txt').read()

# %%
from konlpy.tag import Kkma

# %%
from konlpy.tag import Mecab # mac 상에서 제일 좋은 한글 형태소 분석기

# %%
kkma = Kkma()

# %%
tokens = kkma.morphs(corpus)

# %%
tokens[:5]
# Out:
# ['대한민국', '헌법', '유구', '하', 'ㄴ']

# %%
ko = Text(tokens)

# %%
len(ko)
# Out:
# 10053

# %% [markdown]
# ***

# %% [markdown]
# ## 정규식으로

# %%
sentence = "The little yellow dog barked at the Persian cat"

# %%
tokens = sentence.split()

# %%
tokens
# Out:
# ['The', 'little', 'yellow', 'dog', 'barked', 'at', 'the', 'Persian', 'cat']

# %%
import nltk

# %%
nltk.pos_tag(tokens) # 형태소 분석 (어절-품사)
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Persian', 'JJ'),
#  ('cat', 'NN')]

# %%
enTags = nltk.pos_tag(tokens)

# %%
sentence = "내 친구는 잠을 많이 잔다."

# %%
kkma.pos(sentence) # 한글 형태소 분석
# Out:
# [('내', 'NP'),
#  ('친구', 'NNG'),
#  ('는', 'JX'),
#  ('잠', 'NNG'),
#  ('을', 'JKO'),
#  ('많이', 'MAG'),
#  ('자', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF')]

# %%
koTags = kkma.pos(sentence)

# %%
enParser = nltk.RegexpParser("NP: {<DT>?<JJ>*<NN.*>*}")

# %%
enChunks = enParser.parse(enTags)

# %%
enChunks.draw()

# %%
koParser = nltk.RegexpParser("""
    NP: {<N.*>*<N.*>?}
    VP: {<M.*>*<V.*>*<E.*>*}
""")

# %%
koChunks = koParser.parse(koTags)

# %%
koChunks.draw()

# %%
koParser = nltk.RegexpParser("""
    NP: {<N.*>*<N.*>?}
    OP: {<N.*>*<JKO>*}
    VP: {<M.*>*<V.*>*<E.*>*}
""")

# %% [markdown]
# ## Collocations
# - 위치 기반으로 하는 유사도 분석
# - 유사도 분석 단어를 긍정으로 쓸 경우 감정 분석이 가능하다.

# %%
from nltk import collocations

# %%
measures = collocations.BigramAssocMeasures()
tagged_words = kkma.pos(corpus)
finder = collocations.BigramCollocationFinder.from_words(tagged_words)
for row in finder.nbest(measures.pmi, 5):
    print(row)
# Out:
# (('가부', 'NNG'), ('동수', 'NNG'))
# (('강제', 'NNG'), ('노역', 'NNG'))
# (('경자', 'NNG'), ('유전', 'NNG'))
# (('고', 'ECS'), ('채취', 'NNG'))
# (('공무', 'NNG'), ('담임', 'NNG'))

# %%
words = [w for (w, t) in tagged_words]
finder = collocations.BigramCollocationFinder.from_words(words)
for row in finder.nbest(measures.pmi, 5):
    print(row)
# Out:
# ('가부', '동수')
# ('강제', '노역')
# ('경자', '유전')
# ('공무', '담임')
# ('공중', '도덕')

# %%
tags = [t for (w, t) in tagged_words]
finder = collocations.BigramCollocationFinder.from_words(tags)
for row in finder.nbest(measures.pmi, 5):
    print(row)
# Out:
# ('XR', 'XSA')
# ('JKC', 'VCN')
# ('EPT', 'EPT')
# ('VCN', 'ECD')
# ('ECD', 'VX')

# %% [markdown]
# ## word Cloud

# %%
ko.vocab()
# Out:
# FreqDist({'의': 532, '하': 457, '.': 359, '에': 328, '는': 281, 'ㄴ다': 243, 'ㄴ': 234, '을': 232, '은': 195, '이': 192, ...})

# %%
type(ko.vocab())
# Out:
# nltk.probability.FreqDist

# %%
for row in ko.vocab().items():
    print(row)
# Out:
# ('대한민국', 11)
# ('헌법', 69)
# ('유구', 1)
# ('하', 457)
# ('ㄴ', 234)
# ('역사', 1)
# ('와', 42)
# ('전통', 1)
# ('에', 328)
# ('빛나', 1)
# ('는', 281)
# ('우리', 3)
# ('대하', 19)
# ('국민', 69)
# ('은', 195)
# ('3', 24)
# ('·', 145)
# ('1', 28)
# ('운동', 3)
# ('으로', 57)
# ('건립', 1)
# ('되', 113)
# ('임시', 3)
# ('정부', 23)
# ('의', 532)
# ('법통', 1)
# ('과', 82)
# ('불의', 2)
# ('항거', 1)
# ('4', 14)
# ('19', 2)
# ('민주', 6)
# ('이념', 1)
# ('을', 232)
# ('계승', 2)
# ('고', 39)
# (',', 101)
# ('조국', 3)
# ('개혁', 1)
# ('평화적', 4)
# ('통일', 9)
# ('사명', 2)
# ('입각', 2)
# ('여', 149)
# ('정의', 2)
# ('인도', 1)
# ('동포애', 1)
# ('로써', 5)
# ('민족', 3)
# ('단결', 1)
# ('공고히', 1)
# ('모든', 37)
# ('사회적', 5)
# ('폐습', 1)
# ('를', 135)
# ('타파', 1)
# ('며', 45)
# ('자율', 2)
# ('조화', 2)
# ('바탕', 1)
# ('자유', 21)
# ('민주적', 4)
# ('기본', 8)
# ('질서', 8)
# ('더욱', 1)
# ('확고히', 1)
# ('하여', 3)
# ('정치', 4)
# ('경제', 18)
# ('사회', 4)
# ('문화', 3)
# ('영역', 4)
# ('있', 99)
# ('어서', 9)
# ('각인', 1)
# ('기회', 4)
# ('균등', 4)
# ('히', 1)
# ('능력', 3)
# ('최고', 3)
# ('도로', 1)
# ('발휘', 1)
# ('게', 6)
# ('권리', 21)
# ('따르', 7)
# ('책임', 5)
# ('의무', 20)
# ('완수', 1)
# ('안', 15)
# ('생활', 8)
# ('향상', 4)
# ('기하', 1)
# ('밖', 1)
# ('항구적', 1)
# ('이', 192)
# ('세계', 1)
# ('평화', 5)
# ('인류', 1)
# ('공영', 1)
# ('이바지', 1)
# ('ㅁ', 6)
# ('으로써', 4)
# ('들', 2)
# ('자손', 1)
# ('안전', 11)
# ('행복', 2)
# ('영원히', 1)
# ('확보', 1)
# ('ㄹ', 141)
# ('것', 7)
# ('다짐', 1)
# ('면서', 1)
# ('1948', 1)
# ('년', 12)
# ('7', 4)
# ('월', 3)
# ('12', 3)
# ('일', 19)
# ('제정', 8)
# ('8', 4)
# ('차', 3)
# ('걸치', 1)
# ('관장', 1)
# ('위헌', 2)
# ('간', 4)
# ('지방', 9)
# ('자치', 9)
# ('쟁의', 1)
# ('소원', 2)
# ('인의', 2)
# ('관중', 2)
# ('인은', 2)
# ('112', 1)
# ('가입', 2)
# ('관여', 2)
# ('113', 1)
# ('인용', 1)
# ('114', 1)
# ('공정', 1)
# ('위원장', 1)
# ('호선', 1)
# ('원의', 1)
# ('법령', 3)
# ('급', 2)
# ('115', 1)
# ('선거인', 1)
# ('명부', 1)
# ('작성', 1)
# ('지시', 2)
# ('당', 1)
# ('116', 1)
# ('관리하', 1)
# ('시키', 1)
# ('117', 1)
# ('주민', 1)
# ('종류', 1)
# ('118', 1)
# ('의회', 2)
# ('선임', 4)
# ('119', 1)
# ('기업', 2)
# ('창의', 1)
# ('존중', 1)
# ('균형', 5)
# ('성장', 1)
# ('안정', 2)
# ('소득', 1)
# ('분배', 1)
# ('시장', 1)
# ('지배', 1)
# ('경제력', 1)
# ('방지', 1)
# ('주체', 1)
# ('민주화', 1)
# ('규제', 2)
# ('120', 1)
# ('광물', 1)
# ('지하', 1)
# ('자원', 3)
# ('수산', 1)
# ('수력', 1)
# ('이용', 5)
# ('자연력', 1)
# ('일정', 1)
# ('채취', 1)
# ('특허', 1)
# ('121', 1)
# ('농지', 4)
# ('경자', 1)
# ('유전', 1)
# ('달성', 2)
# ('소작', 1)
# ('금지', 1)
# ('농업', 2)
# ('생산성', 1)
# ('제고', 1)
# ('합리', 1)
# ('불가피', 1)
# ('사정', 1)
# ('임대차', 1)
# ('위탁', 1)
# ('경영', 2)
# ('122', 1)
# ('모두', 1)
# ('생산', 1)
# ('기반', 1)
# ('효율적', 1)
# ('과하', 1)
# ('123', 1)
# ('어업', 1)
# ('육성', 5)
# ('농', 3)
# ('어촌', 1)
# ('종합', 1)
# ('지원', 1)
# ('지역', 2)
# ('중소기업', 2)
# ('농수산물', 1)
# ('수급', 1)
# ('유통', 1)
# ('개선', 1)
# ('가격', 1)
# ('도모', 1)
# ('어민', 2)
# ('자조', 1)
# ('124', 1)
# ('건전', 1)
# ('소비', 1)
# ('계도', 1)
# ('생산품', 1)
# ('품질', 1)
# ('촉구', 1)
# ('소비자', 1)
# ('125', 1)
# ('무역', 1)
# ('126', 1)
# ('국방상', 1)
# ('길', 1)
# ('사영', 1)
# ('공유', 1)
# ('통제', 1)
# ('127', 1)
# ('기술', 1)
# ('혁신', 1)
# ('정보', 1)
# ('인력', 1)
# ('표준', 1)
# ('확립', 1)
# ('기구', 1)
# ('128', 1)
# ('제안', 3)
# ('연장', 1)
# ('당시', 6)
# ('129', 1)
# ('공고', 2)
# ('130', 1)
# ('투표자', 1)
# ('펴', 1)
# ('침', 1)
# ('부칙', 2)
# ('<', 1)
# ('호', 1)
# ('1987.10', 1)
# ('>', 1)
# ('보기', 1)
# ('1988', 1)
# ('준비', 1)
# ('최초', 7)
# ('일로', 3)
# ('전일', 2)
# ('임원', 1)
# ('임명권', 1)
# ('전임자', 1)
# ('판사', 1)
# ('단서', 1)
# ('불구하', 1)
# ('적용', 1)
# ('지속', 1)
# ('새로', 1)
# ('새롭', 1)
# ('존속', 1)

# %%
import csv
with open('words.csv', 'w', encoding = 'utf-8') as f:
    f.write('word, freq\n')
    writer = csv.writer(f)
    for (k, n) in ko.vocab().items():
        f.write('{0}, {1}\n'.format(k, n))

# %% [markdown]
# ## WordCloud

# %%
from collections import Counter

# %%
import pytagcloud
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tokens = [k for (k, v) in kkma.pos(corpus) if v.startswith('NN')]

# %%
tags = Counter(tokens)

# %%
tags  = tags.most_common(40)

# %%
tagList = pytagcloud.make_tags(tags, maxsize=40)

# %%
tagList
# Out:
# [{'color': (51, 205, 185), 'size': 44, 'tag': '법률'},
#  {'color': (173, 60, 12), 'size': 35, 'tag': '수'},
#  {'color': (60, 93, 182), 'size': 33, 'tag': '대통령'},
#  {'color': (160, 146, 190), 'size': 30, 'tag': '국가'},
#  {'color': (190, 169, 186), 'size': 29, 'tag': '헌법'},
#  {'color': (142, 136, 32), 'size': 29, 'tag': '국민'},
#  {'color': (38, 81, 179), 'size': 26, 'tag': '조'},
#  {'color': (21, 164, 178), 'size': 25, 'tag': '국회'},
#  {'color': (51, 207, 150), 'size': 25, 'tag': '때'},
#  {'color': (111, 171, 88), 'size': 20, 'tag': '회의'},
#  {'color': (130, 104, 152), 'size': 19, 'tag': '바'},
#  {'color': (68, 203, 146), 'size': 16, 'tag': '필요'},
#  {'color': (152, 32, 165), 'size': 16, 'tag': '위원'},
#  {'color': (135, 44, 116), 'size': 16, 'tag': '국무'},
#  {'color': (160, 144, 167), 'size': 15, 'tag': '기타'},
#  {'color': (204, 29, 19), 'size': 15, 'tag': '선거'},
#  {'color': (81, 145, 173), 'size': 14, 'tag': '보장'},
#  {'color': (140, 66, 209), 'size': 13, 'tag': '정부'},
#  {'color': (66, 40, 192), 'size': 13, 'tag': '사항'},
#  {'color': (28, 115, 86), 'size': 13, 'tag': '의원'},
#  {'color': (76, 69, 220), 'size': 13, 'tag': '항'},
#  {'color': (140, 132, 168), 'size': 13, 'tag': '자유'},
#  {'color': (190, 23, 121), 'size': 13, 'tag': '권리'},
#  {'color': (209, 124, 60), 'size': 13, 'tag': '국'},
#  {'color': (198, 31, 81), 'size': 13, 'tag': '모든'},
#  {'color': (38, 187, 192), 'size': 12, 'tag': '의무'},
#  {'color': (24, 154, 173), 'size': 12, 'tag': '제'},
#  {'color': (57, 167, 153), 'size': 12, 'tag': '일'},
#  {'color': (59, 168, 109), 'size': 12, 'tag': '직무'},
#  {'color': (199, 179, 218), 'size': 12, 'tag': '임명'},
#  {'color': (143, 95, 208), 'size': 12, 'tag': '경제'},
#  {'color': (39, 12, 37), 'size': 12, 'tag': '조직'},
#  {'color': (176, 73, 52), 'size': 12, 'tag': '이상'},
#  {'color': (107, 193, 16), 'size': 12, 'tag': '국회의원'},
#  {'color': (162, 77, 201), 'size': 12, 'tag': '임기'},
#  {'color': (95, 156, 41), 'size': 11, 'tag': '공무원'},
#  {'color': (189, 210, 36), 'size': 11, 'tag': '경우'},
#  {'color': (140, 49, 74), 'size': 11, 'tag': '법원'},
#  {'color': (89, 115, 217), 'size': 11, 'tag': '의결'},
#  {'color': (131, 59, 148), 'size': 11, 'tag': '단체'}]

# %%
pytagcloud.create_tag_image(tagList, "wordcloud.jpg", fontname = "godoMaum")
