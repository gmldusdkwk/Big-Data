# %% [markdown]
# # Folium

# %%
# !pip install folium
# Out:
# ...
#     100% |████████████████████████████████| 81kB 759kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for folium ... done
#   Stored in directory: /Users/limheeyeon/Library/Caches/pip/wheels/f8/98/ff/954791afc47740d554f0d9e5885fa09dd60c2265d42578e665
# Successfully built folium
# ...

# %%
import folium

# %%
from IPython import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
m = folium.Map(location=[37.5665, 126.9780])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pusan = folium.Map(location = [35.1046, 129.0432], tiles='Mapbox Bright')

# %%
pusan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pusan = folium.Map(location = [35.1046, 129.0432], tiles='stamentoner')

# %%
pusan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.features.CircleMarker(location = [37.5311, 126.9113], redius=50, popup = 'Laurelhurst Park', color = '#3186cc', fill = True, fill_color='#3186cc').add_to(m)

# %%
folium.features.Circle(radius=100, location=[37.5248, 126.9375], popup='The Waterfront', color='crimson', fill=False).add_to(m)

# %%
folium.features.PolygonMarker(locations=[37.5248, 126.9375], popup='The Waterfront', color='crimson').add_to(m)

# %%
m = folium.Map(
    location=[37.5665, 126.9780],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker([37.5165, 126.9680], popup='<i>Mt. Hood Meadows</i>',icon = folium.Icon(icon='cloud')).add_to(m)
folium.Marker([37.5265, 126.9980], popup='<b>Timberline Lodge</b>').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[37.5665, 126.9780],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.features.Circle(
    radius=100,
    location=[37.5248, 126.9375],
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

folium.features.CircleMarker(
    location=[37.5311, 126.9113],
    radius=50,
    popup='Laurelhurst Park',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.features.PolygonMarker(
    locations=[[37.5248, 126.9375],[37.5665, 126.9780],[37.5311, 126.9113]], 
    popup='The Waterfront', 
    color='crimson'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[37.5665, 126.9780], tiles='Stamen Terrain', zoom_start=13)
m.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m=folium.Map(location=[37.5665, 126.9780], tiles='Stamen Terrain')
m.add_child(folium.ClickForMarker(popup="ClickPoint"))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import os
v1 = os.path.join('v1.json')

# %%
json.load(open(v1))
# Out:
# {'mark': 'line',
#  'encoding': {'x': {'field': 'index', 'type': 'quantitative'},
#   'y': {'field': 'value', 'type': 'nominal'},
#   'color': {'field': 'variable', 'type': 'nominal'}},
#  '$schema': 'https://vega.github.io/schema/vega-lite/v2.json',
#  'width': 450,
#  'height': 300,
#  'selection': {'grid': {'type': 'interval',
#    'bind': 'scales',
#    'on': '[mousedown, window:mouseup] > window:mousemove!',
#    'encodings': ['x', 'y'],
#    'translate': '[mousedown, window:mouseup] > window:mousemove!',
#    'zoom': 'wheel!',
#    'mark': {'fill': '#333', 'fillOpacity': 0.125, 'stroke': 'white'},
#    'resolve': 'global'}},
#  'data': {'values': [{'index': 0, 'variable': 'sepal_length', 'value': 5.1},
#    {'index': 1, 'variable': 'sepal_length', 'value': 4.9},
#    {'index': 2, 'variable': 'sepal_length', 'value': 4.7},
#    {'index': 3, 'variable': 'sepal_length', 'value': 4.6},
#    {'index': 4, 'variable': 'sepal_length', 'value': 5},
# ...

# %%
import json

# %%
m8 = folium.Map(location=[37.5665, 126.9780], tiles='Stamen Terrain')


folium.RegularPolygonMarker(
    location=[37.5665, 126.9780],
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open(v1)), width=450, height=250))
).add_to(m8)


# folium.RegularPolygonMarker(
#     [37.5665, 126.9780], 
#     fill_color= '#132b5e', 
#     radius=5,
#     popup=folium.Popup(max_width=450).add_child(
#         folium.Vega(json.load(open(v1)), width=450, height=250))
# ).add_to(m8)

# folium.RegularPolygonMarker(
#     [37.4665, 126.9780],
#     fill_color='#45647d',
#     radius=10,
#     popup=folium.Popup(max_width=450).add_child(
#         folium.Vega(json.load(open(v1)), width=450, height=250))
# ).add_to(m8)

m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import seaborn as sns
import pandas as pd
import pdvega

# %%
data = sns.load_dataset('iris')

# %%
data.vgplot.line()
# Out:
# <div class="vega-embed" id="be7d261c-a7e8-40bd-863d-67fc88c95e0d"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
m9 = folium.Map(location=[37.5665, 126.9780], tiles='Mapbox Bright')

seoul_geo_json=r'seoul_municipalities_geo_simple.json'
folium.GeoJson(seoul_geo_json, name='geojson').add_to(m9)
m9
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m10 = folium.Map(location=[37.5665, 126.9780], tiles='Mapbox Bright')

seoul_topo_json=r'seoul_municipalities_topo_simple.json'
folium.TopoJson(open(seoul_topo_json), "objects.seoul_municipalities_geo", name='topojson').add_to(m10)
m10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Geopandas

# %%
# !pip install geopandas
# Out:
# ...
#     100% |████████████████████████████████| 901kB 11.2MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 4.4MB 7.1MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 1.6MB 9.7MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 21.6MB 2.1MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for pyproj ... done
#   Stored in directory: /Users/limheeyeon/Library/Caches/pip/wheels/89/77/ec/a537585d1022dafde0317dd19d33c4a30d4ee61e19f25ebd8e
#   Running setup.py bdist_wheel for munch ... done
#   Stored in directory: /Users/limheeyeon/Library/Caches/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
#   Running setup.py bdist_wheel for click-plugins ... done
#   Stored in directory: /Users/limheeyeon/Library/Caches/pip/wheels/bc/86/aa/7680e54728998edc1e966a20249b920e582012ed6bdd3815c4
# Successfully built pyproj munch click-plugins
# ...

# %%
import geopandas

# %%
m11 = folium.Map(location=[37.5665, 126.9780], tiles='Mapbox Bright')

seoul_geo_json=r'seoul_municipalities_geo_simple.json'
seoul_geo_df=pd.read_csv('seoul_geo_df.csv')

m11.choropleth(
    geo.
)

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /anaconda3/lib/python3.6/site-packages (18.0)

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# !pip --version
# Out:
# pip 18.0 from /anaconda3/lib/python3.6/site-packages/pip (python 3.6)
