# %%
import pandas as pd

# %%
df = pd.read_csv("pew.txt", sep = '\t')

# %%
df = df.set_index('religion')

# %% [markdown]
# ## Stack
# 1. stack 첫 번째 열부터 쌓는다.
# 2. unstack 첫 번째 열을 푼다.

# %%
type(df.stack())
# Out:
# pandas.core.series.Series

# %%
df = df.stack()

# %%
df
# Out:
# religion
# Agnostic               <$10k                  27
#                        $10-20k                34
#                        $20-30k                60
#                        $30-40k                81
#                        $40-50k                76
#                        $50-75k               137
#                        $75-100k              122
#                        $100-150k             109
#                        >150k                  84
#                        Don't know/refused     96
# Atheist                <$10k                  12
#                        $10-20k                27
#                        $20-30k                37
#                        $30-40k                52
#                        $40-50k                35
#                        $50-75k                70
#                        $75-100k               73
#                        $100-150k              59
#                        >150k                  74
# ...

# %%
df.unstack()
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# religion
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
df = df.unstack()

# %%
df.index = df.index.rename('A')

# %%
df
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# A
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
df['<$10k'].rename('B')
# Out:
# A
# Agnostic                    27
# Atheist                     12
# Buddhist                    27
# Catholic                   418
# Don’t know/refused          15
# Evangelical Prot           575
# Hindu                        1
# Historically Black Prot    228
# Jehovah's Witness           20
# Jewish                      19
# Mainline Prot              289
# Mormon                      29
# Muslim                       6
# Orthodox                    13
# Other Christian              9
# Other Faiths                20
# Other World Religions        5
# Unaffiliated               217
# Name: B, dtype: int64

# %%
df.index.rename('religion', inplace = True)

# %%
df.reset_index()
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Agnostic to Unaffiliated
# Data columns (total 10 columns):
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#             <$10k     $10-20k      $20-30k     $30-40k     $40-50k  \
# count   18.000000   18.000000    18.000000   18.000000   18.000000
# mean   107.222222  154.500000   186.500000  183.444444  171.388889
# std    168.931784  255.172433   309.891869  291.470354  271.144446
# min      1.000000    2.000000     3.000000    4.000000    2.000000
# 25%     12.250000   14.750000    17.000000   15.750000   15.000000
# 50%     20.000000   27.000000    33.500000   40.000000   34.000000
# 75%    170.000000  193.000000   192.000000  198.750000  166.750000
# max    575.000000  869.000000  1064.000000  982.000000  881.000000
#
#            $50-75k    $75-100k   $100-150k       >150k  Don't know/refused
# count    18.000000   18.000000   18.000000   18.000000           18.000000
# mean    288.055556  221.666667  177.611111  144.888889          340.055556
# std     458.442436  345.078849  275.679724  205.224952          530.523878
# ...

# %%
data = pd.read_table("weather.txt")

# %%
data
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
data = data.melt(['id', 'year','month','element']).dropna()

# %%
data.reset_index(drop = 'index', inplace = True)

# %%
data = data.sort_values('month').reset_index(drop = True)

# %%
data
# Out:
#              id  year  month element variable  value
# 0   MX000017004  2010      1    TMIN      d30  145.0
# 1   MX000017004  2010      1    TMAX      d30  278.0
# 2   MX000017004  2010      2    TMIN      d23  107.0
# 3   MX000017004  2010      2    TMAX       d2  273.0
# 4   MX000017004  2010      2    TMIN       d2  144.0
# 5   MX000017004  2010      2    TMAX       d3  241.0
# 6   MX000017004  2010      2    TMIN       d3  144.0
# 7   MX000017004  2010      2    TMIN      d11  134.0
# 8   MX000017004  2010      2    TMAX      d11  297.0
# 9   MX000017004  2010      2    TMAX      d23  299.0
# 10  MX000017004  2010      3    TMIN      d10  168.0
# 11  MX000017004  2010      3    TMIN       d5  142.0
# 12  MX000017004  2010      3    TMAX      d10  345.0
# 13  MX000017004  2010      3    TMAX      d16  311.0
# 14  MX000017004  2010      3    TMIN      d16  176.0
# 15  MX000017004  2010      3    TMAX       d5  321.0
# 16  MX000017004  2010      4    TMAX      d27  363.0
# ...

# %% [markdown]
# ## Category
# 적은 수의 object는 category로 변경

# %%
data.element = data.element.astype('category')

# %%
data.element.describe()
# Out:
# count       66
# unique       2
# top       TMIN
# freq        33
# Name: element, dtype: object

# %%
data.element.cat.codes  # 숫자로 matching encoding!
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     0
# 10    1
# 11    1
# 12    0
# 13    0
# 14    1
# 15    0
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# 26    0
# 27    1
# 28    1
# 29    0
#      ..
# 36    0
# 37    1
# 38    0
# 39    1
# 40    0
# 41    0
# 42    1
# 43    0
# 44    1
# 45    0
# 46    0
# 47    1
# 48    0
# 49    1
# 50    1
# 51    0
# 52    0
# 53    1
# 54    1
# 55    0
# 56    0
# 57    0
# 58    1
# 59    0
# 60    1
# 61    1
# 62    0
# 63    1
# 64    1
# 65    0
# Length: 66, dtype: int8

# %%
data1 = pd.read_json('nobel_winners_dirty.json')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %%
data1.category = data1.category.astype('category')

# %%
data1.date_of_birth = pd.to_datetime(data1.date_of_birth)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null category
# country           1052 non-null object
# date_of_birth     1043 non-null datetime64[ns]
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: category(1), datetime64[ns](1), int64(1), object(9)
# memory usage: 91.9+ KB

# %%
import seaborn as sns

# %%
import pdvega

# %%
data2 = sns.load_dataset('tips')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
data2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data2.groupby('smoker').mean().tip
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
data2.groupby(['sex', 'smoker']).mean()
# Out:
#                total_bill       tip      size
# sex    smoker
# Male   Yes      22.284500  3.051167  2.500000
#        No       19.791237  3.113402  2.711340
# Female Yes      17.977879  2.931515  2.242424
#        No       18.105185  2.773519  2.592593

# %%
data4 = data2.groupby(['smoker']).mean().tip

# %%
data4[0]
# Out:
# 3.0087096774193549

# %%
data4.index[0]
# Out:
# 'Yes'

# %%
[float(data4[0]), float(data4[1])]
# Out:
# [3.008709677419355, 2.9918543046357624]

# %%
[data4.index[0], data4.index[1]]
# Out:
# ['Yes', 'No']

# %%
data4
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
pd.pivot_table(data2, values = ['tip'], index = ['sex', 'smoker'])
# Out:
#                     tip
# sex    smoker
# Female No      2.773519
#        Yes     2.931515
# Male   No      3.113402
#        Yes     3.051167

# %%
graph = pd.pivot_table(data2, values = ['tip'], index = ['sex'])

# %%
graph
# Out:
#              tip
# sex
# Female  2.833448
# Male    3.089618

# %% [markdown]
# # Visualization

# %%
graph.plot.bar()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')  ##ggplot 기반으로 변경

# %%
graph.plot.bar()

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('seaborn-bright')

# %%
graph.vgplot.bar() # python 다형성
# Out:
# <div class="vega-embed" id="53c54f81-af9e-49d3-8e07-eda1bf08b1c3"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
sns.barplot(graph)

# %%
sns.barplot(graph, orient = 'vertical')

# %%
sns.barplot(graph.T)

# %%
data2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data2.groupby('day').mean().tip
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
data2.groupby('day').mean().tip.vgplot.bar()
# Out:
# <div class="vega-embed" id="c40181ab-2a63-47dd-aeb7-7ebf2b3f4b8e"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
iris = sns.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
sns.pairplot(iris, hue='species')
