# %% [markdown]
# # 데이터 전처리 과정

# %% [markdown]
# ## Pandas Data type
# 1. object: string
# 2. int 64
# 3. float 64
# 4. category: 문자이지만 경우가 한정되어 있는 경우 (남자, 여자)
# 5. datetime

# %%
import pandas as pd 
data = pd.read_json('nobel_winners_dirty.json')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %%
data.head()
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                          Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature             9 October 1892
# 2  Bosnia and Herzegovina               Chemistry              July 23, 1906
# 3                                           Peace    Belgium            None
# 4                                           Peace    Belgium    26 July 1829
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                               name  \
# ...

# %%
data.describe(include = 'all')  # 문자 데이터에 대한 describe가 다 나온다.
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
# mean       NaN                     NaN            NaN              NaN
# std        NaN                     NaN            NaN              NaN
# min        NaN                     NaN            NaN              NaN
# 25%        NaN                     NaN            NaN              NaN
# 50%        NaN                     NaN            NaN              NaN
# 75%        NaN                     NaN            NaN              NaN
# max        NaN                     NaN            NaN              NaN
#
#        date_of_death gender                                         link  \
# ...

# %%
data.describe(include = ['object']) #string discribe
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                   name place_of_birth place_of_death  \
# count             1052           1044           1044
# unique             998            735            410
# top     Charles K. Kao
# freq                 2             29            409
#
# ...

# %%
data.dtypes
# Out:
# born_in           object
# category          object
# country           object
# date_of_birth     object
# date_of_death     object
# gender            object
# link              object
# name              object
# place_of_birth    object
# place_of_death    object
# text              object
# year               int64
# dtype: object

# %%
data.shape
# Out:
# (1052, 12)

# %% [markdown]
# ## Aggregation
# - 지역별로 몇 명 있는지 확인할 수 있다.

# %% [markdown]
# ## 한 열에 행의 개수가 다를 경우
# 1. 비어있는 것을 제거
# 2. 비어있는 것을 채운다. interpolation
#  1. 평균
#  2. 가까이에 있는 것

# %%
data.sort_values('year')
# Out:
#             born_in                category         country  \
# 959                               Chemistry         Finland
# 958                              Literature         Finland
# 960                  Physiology or Medicine         Finland
# 743                               Chemistry     Netherlands
# 68                   Physiology or Medicine         Germany
# 67                                  Physics         Germany
# 908                                   Peace          France
# 909                                   Peace          France
# 608                                   Peace     Switzerland
# 907                              Literature          France
# 610                                   Peace     Switzerland
# 609                                   Peace     Switzerland
# 69                               Literature         Germany
# 70                                Chemistry         Germany
# 745                                 Physics     Netherlands
# ...

# %%
data.loc[data['category'] == 'Chemistry', 'country']
# Out:
# 2
# 12             Belgium
# 26             Denmark
# 30      Czech Republic
# 33              France
# 34              France
# 49             Germany
# 52             Germany
# 59             Germany
# 60             Germany
# 61             Germany
# 70             Germany
# 71             Germany
# 74             Germany
# 77             Germany
# 94              Israel
# 95              Israel
# 101
# 106
# 109
# 121       South Africa
# 128
# 131     United Kingdom
# 138
# 142     United Kingdom
# 143     United Kingdom
# 144     United Kingdom
# 151     United Kingdom
# 157     United Kingdom
# 167      United States
#              ...
# 889
# 902            Germany
# 906            Germany
# 914             France
# 919             France
# 920             France
# 921             France
# 924
# 935
# 942             France
# 949             France
# 959            Finland
# 965              Egypt
# 972
# 985             Canada
# 987
# 990             Canada
# 993
# ...

# %%
len(data[data['category'] == 'Chemistry'].country.unique())
# Out:
# 25

# %%
len(data.columns)
# Out:
# 12

# %%
data.columns[0]
# Out:
# 'born_in'

# %%
data2 = data.sort_values('name').set_index('name').reset_index()

# %%
data2 #sort by name
# Out:
#                                                    name      born_in  \
# 0                                     A. Michael Spence
# 1                                             Aage Bohr
# 2                                     Aaron Ciechanover
# 3                                            Aaron Klug
# 4                                            Aaron Klug
# 5                                          Aaron Klug *    Lithuania
# 6                                           Abdus Salam
# 7                                         Ada E. Yonath
# 8                                         Adam G. Riess
# 9                                       Adolf Butenandt
# 10                          Adolf Otto Reinhold Windaus
# 11                                     Adolf von Baeyer
# 12                                Adolfo Pérez Esquivel
# 13                                      Ahmed H. Zewail
# 14                                         Ahmed Zewail
# ...

# %%
bi_col = data.born_in

# %%
bi_col.head()
# Out:
# 0
# 1    Bosnia and Herzegovina
# 2    Bosnia and Herzegovina
# 3
# 4
# Name: born_in, dtype: object

# %%
type(bi_col)
# Out:
# pandas.core.series.Series

# %%
data.set_index('name').iloc[0]
# Out:
# born_in
# category                                    Physiology or Medicine
# country                                                  Argentina
# date_of_birth                                       8 October 1927
# date_of_death                                        24 March 2002
# gender                                                        male
# link              http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# place_of_birth                           Bahía Blanca ,  Argentina
# place_of_death                                 Cambridge , England
# text                 César Milstein , Physiology or Medicine, 1984
# year                                                          1984
# Name: César Milstein, dtype: object

# %%
data.set_index('name', drop=True).loc['César Milstein']
# Out:
#                born_in                category         country  \
# name
# César Milstein          Physiology or Medicine       Argentina
# César Milstein          Physiology or Medicine  United Kingdom
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# César Milstein  8 October 1927  24 March 2002   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
#
#                            place_of_birth       place_of_death  \
# name
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
# César Milstein  Bahía Blanca ,  Argentina  Cambridge , England
#
#                                                              text  year
# name
# César Milstein      César Milstein , Physiology or Medicine, 1984  1984
# ...

# %%
data2.set_index('name', drop=True, inplace=True)

# %%
data2.head(8)
# Out:
#                      born_in   category         country     date_of_birth  \
# name
# A. Michael Spence             Economics   United States  November 7, 1943
# Aage Bohr                       Physics         Denmark      19 June 1922
# Aaron Ciechanover             Chemistry          Israel   October 1, 1947
# Aaron Klug                    Chemistry  United Kingdom    11 August 1926
# Aaron Klug                    Chemistry    South Africa    11 August 1926
# Aaron Klug *       Lithuania  Chemistry                    11 August 1926
# Abdus Salam                     Physics        Pakistan   29 January 1926
# Ada E. Yonath                 Chemistry          Israel     June 22, 1939
#
#                       date_of_death  gender  \
# name
# A. Michael Spence                      male
# Aage Bohr          8 September 2009    male
# Aaron Ciechanover                      male
# Aaron Klug                             male
# Aaron Klug                             male
# ...

# %%
mask = data.year > 2000
winners_sinces_2000 = data.year[mask]

# %%
winners_sinces_2000.head()
# Out:
# 13    2013
# 32    2010
# 66    2001
# 87    2002
# 88    2007
# Name: year, dtype: int64

# %% [markdown]
# ## Function Paradaim

# %%
data.born_in.apply(type)  #type이라는 함수를 하나의 행마다 실행한다.
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29      <class 'str'>
#             ...
# 1022    <class 'str'>
# 1023    <class 'str'>
# 1024    <class 'str'>
# 1025    <class 'str'>
# 1026    <class 'str'>
# 1027    <class 'str'>
# 1028    <class 'str'>
# 1029    <class 'str'>
# 1030    <class 'str'>
# 1031    <class 'str'>
# ...

# %%
set(data.born_in.apply(type))  # show the type of the 'born_in' column
# Out:
# {str}

# %%
data.born_in.apply(len) # apply can be used in DataFrame
# Out:
# 0        0
# 1       22
# 2       22
# 3        0
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       7
# 15       7
# 16       7
# 17       0
# 18       0
# 19       0
# 20       0
# 21       0
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27      14
# 28      14
# 29      14
#         ..
# 1022     0
# 1023     7
# 1024     7
# 1025     0
# 1026     0
# 1027     7
# 1028     0
# 1029     0
# 1030     7
# 1031     7
# 1032     0
# 1033     0
# 1034     7
# 1035     9
# 1036     0
# 1037     0
# 1038     0
# 1039     9
# 1040     0
# 1041     9
# 1042     0
# 1043     0
# 1044     0
# 1045     0
# 1046     9
# 1047     0
# 1048     0
# 1049     0
# 1050     0
# 1051     0
# Name: born_in, Length: 1052, dtype: int64

# %%
data.born_in.map(type) # map only can be used in series
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29      <class 'str'>
#             ...
# 1022    <class 'str'>
# 1023    <class 'str'>
# 1024    <class 'str'>
# 1025    <class 'str'>
# 1026    <class 'str'>
# 1027    <class 'str'>
# 1028    <class 'str'>
# 1029    <class 'str'>
# 1030    <class 'str'>
# 1031    <class 'str'>
# ...

# %% [markdown]
# ## Data Cleaning
# - 비어있는 것을 'unknown'으로 대체

# %%
def unknown(x):
    if len(x):
        return x
    return 'unknown'
data.born_in = data.born_in.apply(unknown)

# %%
data.info()  # born_in 1052
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           1052 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %%
import numpy as np
bi_col.replace('unknown', np.nan, inplace = True)  # change series

# %%
data.born_in.head()
# Out:
# 0                       NaN
# 1    Bosnia and Herzegovina
# 2    Bosnia and Herzegovina
# 3                       NaN
# 4                       NaN
# Name: born_in, dtype: object

# %%
data.info()  # born_in 142
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
# born_in           142 non-null object
# category          1052 non-null object
# country           1052 non-null object
# date_of_birth     1044 non-null object
# date_of_death     1044 non-null object
# gender            1040 non-null object
# link              1052 non-null object
# name              1052 non-null object
# place_of_birth    1044 non-null object
# place_of_death    1044 non-null object
# text              1052 non-null object
# year              1052 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 98.7+ KB

# %%
data.replace("", np.nan, inplace = True)  # change all DataFrame

# %%
data.head()
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                     NaN  Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature        NaN  9 October 1892
# 2  Bosnia and Herzegovina               Chemistry        NaN   July 23, 1906
# 3                     NaN                   Peace    Belgium            None
# 4                     NaN                   Peace    Belgium    26 July 1829
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                               name  \
# ...

# %% [markdown]
# ## 필요없는 부분 제거

# %%
data['name'] = data.loc[data.name.str.contains('\*'), 'name'].str.replace('*','')

# %%
data['name'].head()
# Out:
# 0                 NaN
# 1         Ivo Andric
# 2    Vladimir Prelog
# 3                 NaN
# 4                 NaN
# Name: name, dtype: object

# %% [markdown]
# ## np.nan: not avaliable number
# ## None: 없는 값

# %%
np.nan == np.nan  # nan은 값을 다 다르게 설정한다. 없는 아이들끼리 메모리 값이 달라진다. 이렇게 하면 연산속도가 빨라진다.
# Out:
# False

# %%
None == False
# Out:
# False

# %%
None == None
# Out:
# True

# %%
data.born_in.isnull()  # 없는 값 inf, None, nan 포함
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %%
data.born_in.isna() # not avaliable number
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1022     True
# 1023    False
# 1024    False
# 1025     True
# 1026     True
# 1027    False
# 1028     True
# 1029     True
# 1030    False
# 1031    False
# 1032     True
# 1033     True
# 1034    False
# 1035    False
# 1036     True
# 1037     True
# 1038     True
# 1039    False
# 1040     True
# 1041    False
# 1042     True
# 1043     True
# 1044     True
# 1045     True
# 1046    False
# 1047     True
# 1048     True
# 1049     True
# 1050     True
# 1051     True
# ...

# %%
set(data.born_in.isna() == data.born_in.isnull())
# Out:
# {True}

# %%
data[data.born_in.isnull() == False]
# Out:
#                      born_in                category country  \
# 1     Bosnia and Herzegovina              Literature     NaN
# 2     Bosnia and Herzegovina               Chemistry     NaN
# 14                   Belarus               Economics     NaN
# 15                   Belarus                   Peace     NaN
# 16                   Belarus                   Peace     NaN
# 27            Czech Republic                   Peace     NaN
# 28            Czech Republic  Physiology or Medicine     NaN
# 29            Czech Republic  Physiology or Medicine     NaN
# 50                   Germany                   Peace     NaN
# 51                   Germany                 Physics     NaN
# 53                   Germany  Physiology or Medicine     NaN
# 58                   Germany                 Physics     NaN
# 63                   Germany                 Physics     NaN
# 82                     Italy  Physiology or Medicine     NaN
# ...

# %%
data.dropna() #axis = 0 이므로 행을 제거
# Out:
# Empty DataFrame
# Columns: [born_in, category, country, date_of_birth, date_of_death, gender, link, name, place_of_birth, place_of_death, text, year]
# Index: []

# %%
data.dropna(axis = 1) #axis = 1 이므로 열을 제거
# Out:
#                                                    link  \
# 0      http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1               http://en.wikipedia.org/wiki/Ivo_Andric
# 2          http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3     http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4     http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# 5      http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# 6        http://en.wikipedia.org/wiki/Henri_La_Fontaine
# 7             http://en.wikipedia.org/wiki/Jules_Bordet
# 8        http://en.wikipedia.org/wiki/Corneille_Heymans
# 9             http://en.wikipedia.org/wiki/Georges_Pire
# 10           http://en.wikipedia.org/wiki/Albert_Claude
# 11       http://en.wikipedia.org/wiki/Christian_de_Duve
# 12          http://en.wikipedia.org/wiki/Ilya_Prigogine
# 13    http://en.wikipedia.org/wiki/Fran%C3%A7ois_Eng...
# 14           http://en.wikipedia.org/wiki/Simon_Kuznets
# 15          http://en.wikipedia.org/wiki/Menachem_Begin
# ...

# %% [markdown]
# ## 중복값 처리
# - 일반적으로는 의미가 없다.

# %%
set(data[data.duplicated('name')].name)
# Out:
# {'Andrew Schally ',
#  'Czesław Miłosz ',
#  'Georges Charpak ',
#  'Menachem Begin ',
#  'Michael Levitt ',
#  'Roald Hoffmann ',
#  'Shimon Peres ',
#  'Wilhelm Ostwald ',
#  nan}

# %%
data.name.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: name, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                      born_in                category    country  \
# 0                        NaN  Physiology or Medicine  Argentina
# 1     Bosnia and Herzegovina              Literature        NaN
# 2     Bosnia and Herzegovina               Chemistry        NaN
# 3                        NaN                   Peace    Belgium
# 4                        NaN                   Peace    Belgium
# 5                        NaN              Literature    Belgium
# 6                        NaN                   Peace    Belgium
# 7                        NaN  Physiology or Medicine    Belgium
# 8                        NaN  Physiology or Medicine    Belgium
# 9                        NaN                   Peace    Belgium
# 10                       NaN  Physiology or Medicine    Belgium
# 11                       NaN  Physiology or Medicine    Belgium
# 12                       NaN               Chemistry    Belgium
# 13                       NaN                 Physics    Belgium
# ...

# %%
data.count()
# Out:
# born_in            142
# category          1046
# country            910
# date_of_birth     1043
# date_of_death      682
# gender            1040
# link              1052
# name               142
# place_of_birth    1015
# place_of_death     635
# text              1052
# year              1052
# dtype: int64

# %%
data.drop_duplicates().count()
# Out:
# born_in            142
# category          1046
# country            910
# date_of_birth     1043
# date_of_death      682
# gender            1040
# link              1052
# name               142
# place_of_birth    1015
# place_of_death     635
# text              1052
# year              1052
# dtype: int64

# %%
pew = pd.read_table('pew.txt')

# %%
pd.read_csv('pew.txt', sep = '\t')
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew[pew.religion == 'Buddhist'].mean(axis = 1)
# Out:
# 2    41.1
# dtype: float64

# %% [markdown]
# ## melt
# - wide -> long

# %%
pew.melt('religion')
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
melt_data  = pew.melt('religion')

# %%
melt_data[melt_data.religion == 'Hindu']
# Out:
#     religion            variable  value
# 6      Hindu               <$10k      1
# 24     Hindu             $10-20k      9
# 42     Hindu             $20-30k      7
# 60     Hindu             $30-40k      9
# 78     Hindu             $40-50k     11
# 96     Hindu             $50-75k     34
# 114    Hindu            $75-100k     47
# 132    Hindu           $100-150k     48
# 150    Hindu               >150k     54
# 168    Hindu  Don't know/refused     37

# %% [markdown]
# ## Group by

# %%
melt_data.groupby('religion').mean()
# Out:
#                          value
# religion
# Agnostic                  82.6
# Atheist                   51.5
# Buddhist                  41.1
# Catholic                 805.4
# Don’t know/refused        27.2
# Evangelical Prot         947.2
# Hindu                     25.7
# Historically Black Prot  199.5
# Jehovah's Witness         21.5
# Jewish                    68.2
# Mainline Prot            747.0
# Mormon                    58.1
# Muslim                    11.6
# Orthodox                  36.3
# Other Christian           12.9
# Other Faiths              44.9
# Other World Religions      4.2
# Unaffiliated             370.7

# %%
melt_data.groupby('religion').min()
# Out:
#                         variable  value
# religion
# Agnostic                 $10-20k     27
# Atheist                  $10-20k     12
# Buddhist                 $10-20k     21
# Catholic                 $10-20k    418
# Don’t know/refused       $10-20k     10
# Evangelical Prot         $10-20k    414
# Hindu                    $10-20k      1
# Historically Black Prot  $10-20k     78
# Jehovah's Witness        $10-20k      6
# Jewish                   $10-20k     19
# Mainline Prot            $10-20k    289
# Mormon                   $10-20k     29
# Muslim                   $10-20k      6
# Orthodox                 $10-20k     13
# Other Christian          $10-20k      7
# Other Faiths             $10-20k     20
# Other World Religions    $10-20k      2
# Unaffiliated             $10-20k    217

# %%
tb = pd.read_csv('tb.csv')

# %%
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5769 entries, 0 to 5768
# Data columns (total 23 columns):
# iso2            5746 non-null object
# year            5769 non-null int64
# new_sp          3081 non-null float64
# new_sp_m04      392 non-null float64
# new_sp_m514     401 non-null float64
# new_sp_m014     2381 non-null float64
# new_sp_m1524    2407 non-null float64
# new_sp_m2534    2408 non-null float64
# new_sp_m3544    2415 non-null float64
# new_sp_m4554    2421 non-null float64
# new_sp_m5564    2414 non-null float64
# new_sp_m65      2408 non-null float64
# new_sp_mu       273 non-null float64
# new_sp_f04      393 non-null float64
# new_sp_f514     404 non-null float64
# new_sp_f014     2378 non-null float64
# new_sp_f1524    2394 non-null float64
# new_sp_f2534    2400 non-null float64
# new_sp_f3544    2398 non-null float64
# new_sp_f4554    2401 non-null float64
# new_sp_f5564    2394 non-null float64
# new_sp_f65      2396 non-null float64
# ...

# %%
tb.head()
# Out:
#   iso2  year  new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0   AD  1989     NaN         NaN          NaN          NaN           NaN
# 1   AD  1990     NaN         NaN          NaN          NaN           NaN
# 2   AD  1991     NaN         NaN          NaN          NaN           NaN
# 3   AD  1992     NaN         NaN          NaN          NaN           NaN
# 4   AD  1993    15.0         NaN          NaN          NaN           NaN
#
#    new_sp_m2534  new_sp_m3544  new_sp_m4554    ...      new_sp_f04  \
# 0           NaN           NaN           NaN    ...             NaN
# 1           NaN           NaN           NaN    ...             NaN
# 2           NaN           NaN           NaN    ...             NaN
# 3           NaN           NaN           NaN    ...             NaN
# 4           NaN           NaN           NaN    ...             NaN
#
#    new_sp_f514  new_sp_f014  new_sp_f1524  new_sp_f2534  new_sp_f3544  \
# ...

# %%
melt_tb = tb.melt(['iso2', 'year'], value_name = '임', var_name = '희연')

# %%
melt_tb
# Out:
#        iso2  year         희연     임
# 0        AD  1989     new_sp   NaN
# 1        AD  1990     new_sp   NaN
# 2        AD  1991     new_sp   NaN
# 3        AD  1992     new_sp   NaN
# 4        AD  1993     new_sp  15.0
# 5        AD  1994     new_sp  24.0
# 6        AD  1996     new_sp   8.0
# 7        AD  1997     new_sp  17.0
# 8        AD  1998     new_sp   1.0
# 9        AD  1999     new_sp   4.0
# 10       AD  2000     new_sp   1.0
# 11       AD  2001     new_sp   3.0
# 12       AD  2002     new_sp   2.0
# 13       AD  2003     new_sp   7.0
# 14       AD  2004     new_sp   3.0
# 15       AD  2005     new_sp   5.0
# 16       AD  2006     new_sp   8.0
# 17       AD  2007     new_sp   2.0
# 18       AD  2008     new_sp   3.0
# 19       AE  1980     new_sp   NaN
# 20       AE  1981     new_sp   NaN
# 21       AE  1982     new_sp   NaN
# 22       AE  1983     new_sp   NaN
# 23       AE  1984     new_sp   NaN
# 24       AE  1985     new_sp   NaN
# 25       AE  1986     new_sp   NaN
# ...

# %%
melt_tb.dropna(inplace = True)

# %%
melt_tb
# Out:
#        iso2  year         희연       임
# 4        AD  1993     new_sp    15.0
# 5        AD  1994     new_sp    24.0
# 6        AD  1996     new_sp     8.0
# 7        AD  1997     new_sp    17.0
# 8        AD  1998     new_sp     1.0
# 9        AD  1999     new_sp     4.0
# 10       AD  2000     new_sp     1.0
# 11       AD  2001     new_sp     3.0
# 12       AD  2002     new_sp     2.0
# 13       AD  2003     new_sp     7.0
# 14       AD  2004     new_sp     3.0
# 15       AD  2005     new_sp     5.0
# 16       AD  2006     new_sp     8.0
# 17       AD  2007     new_sp     2.0
# 18       AD  2008     new_sp     3.0
# 35       AE  1999     new_sp    31.0
# 36       AE  2000     new_sp    73.0
# 37       AE  2001     new_sp    69.0
# 38       AE  2002     new_sp    57.0
# 39       AE  2003     new_sp    77.0
# 40       AE  2004     new_sp    57.0
# 41       AE  2005     new_sp    62.0
# 42       AE  2006     new_sp    52.0
# 43       AE  2007     new_sp    56.0
# ...

# %%
melt_tb.groupby('year').sum()
# Out:
#               임
# year
# 1980     9309.0
# 1981     8692.0
# 1982     8030.0
# 1983     8223.0
# 1984    11838.0
# 1985    13929.0
# 1986    15389.0
# 1987    22413.0
# 1988    25347.0
# 1989    25714.0
# 1990    29185.0
# 1991    29708.0
# 1992    33323.0
# 1993   811968.0
# 1994   918563.0
# 1995  1687867.0
# 1996  1962020.0
# 1997  2098090.0
# 1998  2247841.0
# 1999  2494576.0
# 2000  2675011.0
# 2001  2846873.0
# 2002  3239720.0
# 2003  3797809.0
# 2004  4397434.0
# 2005  4763678.0
# 2006  5041842.0
# 2007  5154589.0
# 2008  5294658.0

# %%
melt_tb.groupby(['year', 'iso2']).sum()
# Out:
#                   임
# year iso2
# 1980 CA      1902.0
#      CK        16.0
#      MN         0.0
#      TZ      7391.0
# 1981 CA      1606.0
#      CK         4.0
#      TZ      7082.0
# 1982 CA      1624.0
#      CK        24.0
#      MN         0.0
#      TZ      6382.0
# 1983 CA      1542.0
#      CK        30.0
#      MN         0.0
#      TZ      6651.0
# 1984 CA      1622.0
#      CK         6.0
#      FJ        82.0
#      LK      2608.0
#      MN         0.0
#      TZ      7520.0
# 1985 CA      1582.0
#      CK        16.0
#      FJ        99.0
#      LK      1935.0
#      MN         0.0
#      MW      2277.0
#      TZ      8020.0
# 1986 CA      1504.0
#      CK         5.0
# ...             ...
# 2008 SV      1986.0
#      SY      2280.0
#      SZ      6278.0
#      TD      6618.0
#      TG      4468.0
#      TH     57576.0
#      TJ      4146.0
#      TK        74.0
#      TL      1734.0
#      TM      2662.0
#      TN      1972.0
#      TO        22.0
# ...

# %%
data3 = pd.read_csv('weather.txt', sep = '\t')

# %%
data3
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
data3 = data3.melt(['id', 'year','month','element']).dropna()

# %%
data3
# Out:
#               id  year  month element variable  value
# 20   MX000017004  2010     12    TMAX       d1  299.0
# 21   MX000017004  2010     12    TMIN       d1  138.0
# 24   MX000017004  2010      2    TMAX       d2  273.0
# 25   MX000017004  2010      2    TMIN       d2  144.0
# 40   MX000017004  2010     11    TMAX       d2  313.0
# 41   MX000017004  2010     11    TMIN       d2  163.0
# 46   MX000017004  2010      2    TMAX       d3  241.0
# 47   MX000017004  2010      2    TMIN       d3  144.0
# 56   MX000017004  2010      7    TMAX       d3  286.0
# 57   MX000017004  2010      7    TMIN       d3  175.0
# 84   MX000017004  2010     11    TMAX       d4  272.0
# 85   MX000017004  2010     11    TMIN       d4  120.0
# 92   MX000017004  2010      3    TMAX       d5  321.0
# 93   MX000017004  2010      3    TMIN       d5  142.0
# 102  MX000017004  2010      8    TMAX       d5  296.0
# 103  MX000017004  2010      8    TMIN       d5  158.0
# ...

# %%
data3.id.unique()
# Out:
# array(['MX000017004'], dtype=object)

# %%
del data3['id']

# %%
data3
# Out:
#      year  month element variable  value
# 20   2010     12    TMAX       d1  299.0
# 21   2010     12    TMIN       d1  138.0
# 24   2010      2    TMAX       d2  273.0
# 25   2010      2    TMIN       d2  144.0
# 40   2010     11    TMAX       d2  313.0
# 41   2010     11    TMIN       d2  163.0
# 46   2010      2    TMAX       d3  241.0
# 47   2010      2    TMIN       d3  144.0
# 56   2010      7    TMAX       d3  286.0
# 57   2010      7    TMIN       d3  175.0
# 84   2010     11    TMAX       d4  272.0
# 85   2010     11    TMIN       d4  120.0
# 92   2010      3    TMAX       d5  321.0
# 93   2010      3    TMIN       d5  142.0
# 102  2010      8    TMAX       d5  296.0
# 103  2010      8    TMIN       d5  158.0
# 104  2010     10    TMAX       d5  270.0
# 105  2010     10    TMIN       d5  140.0
# 106  2010     11    TMAX       d5  263.0
# 107  2010     11    TMIN       d5   79.0
# 130  2010     12    TMAX       d6  278.0
# 131  2010     12    TMIN       d6  105.0
# ...

# %%
data3.reset_index(drop = 'index', inplace = True)

# %%
data3
# Out:
#     year  month element variable  value
# 0   2010     12    TMAX       d1  299.0
# 1   2010     12    TMIN       d1  138.0
# 2   2010      2    TMAX       d2  273.0
# 3   2010      2    TMIN       d2  144.0
# 4   2010     11    TMAX       d2  313.0
# 5   2010     11    TMIN       d2  163.0
# 6   2010      2    TMAX       d3  241.0
# 7   2010      2    TMIN       d3  144.0
# 8   2010      7    TMAX       d3  286.0
# 9   2010      7    TMIN       d3  175.0
# 10  2010     11    TMAX       d4  272.0
# 11  2010     11    TMIN       d4  120.0
# 12  2010      3    TMAX       d5  321.0
# 13  2010      3    TMIN       d5  142.0
# 14  2010      8    TMAX       d5  296.0
# 15  2010      8    TMIN       d5  158.0
# 16  2010     10    TMAX       d5  270.0
# 17  2010     10    TMIN       d5  140.0
# 18  2010     11    TMAX       d5  263.0
# 19  2010     11    TMIN       d5   79.0
# 20  2010     12    TMAX       d6  278.0
# 21  2010     12    TMIN       d6  105.0
# ...

# %%
data3.year.unique()
# Out:
# array([2010])

# %%
data3 = data3.sort_values('month').reset_index(drop = True)

# %%
data3
# Out:
#     year  month element variable  value
# 0   2010      1    TMIN      d30  145.0
# 1   2010      1    TMAX      d30  278.0
# 2   2010      2    TMIN      d23  107.0
# 3   2010      2    TMAX       d2  273.0
# 4   2010      2    TMIN       d2  144.0
# 5   2010      2    TMAX       d3  241.0
# 6   2010      2    TMIN       d3  144.0
# 7   2010      2    TMIN      d11  134.0
# 8   2010      2    TMAX      d11  297.0
# 9   2010      2    TMAX      d23  299.0
# 10  2010      3    TMIN      d10  168.0
# 11  2010      3    TMIN       d5  142.0
# 12  2010      3    TMAX      d10  345.0
# 13  2010      3    TMAX      d16  311.0
# 14  2010      3    TMIN      d16  176.0
# 15  2010      3    TMAX       d5  321.0
# 16  2010      4    TMAX      d27  363.0
# 17  2010      4    TMIN      d27  167.0
# 18  2010      5    TMAX      d27  332.0
# 19  2010      5    TMIN      d27  182.0
# 20  2010      6    TMAX      d29  301.0
# 21  2010      6    TMAX      d17  280.0
# ...

# %%
data3[data3.element == 'TMIN'].groupby('month').mean()
# Out:
#        year       value
# month
# 1      2010  145.000000
# 2      2010  132.250000
# 3      2010  162.000000
# 4      2010  167.000000
# 5      2010  182.000000
# 6      2010  177.500000
# 7      2010  170.000000
# 8      2010  158.428571
# 10     2010  130.800000
# 11     2010  125.000000
# 12     2010  121.500000

# %% [markdown]
# ## Groupby 와 유사
# 1. pivot
# 2. pivot table
# 3.

# %%
pd.pivot_table(data3, index = 'month', values = 'value')  # 기본이 mean
# Out:
#             value
# month
# 1      211.500000
# 2      204.875000
# 3      243.833333
# 4      265.000000
# 5      257.000000
# 6      234.000000
# 7      231.250000
# 8      220.571429
# 10     209.900000
# 11     203.100000
# 12     205.000000

# %%
data3.groupby('month').mean()
# Out:
#        year       value
# month
# 1      2010  211.500000
# 2      2010  204.875000
# 3      2010  243.833333
# 4      2010  265.000000
# 5      2010  257.000000
# 6      2010  234.000000
# 7      2010  231.250000
# 8      2010  220.571429
# 10     2010  209.900000
# 11     2010  203.100000
# 12     2010  205.000000
